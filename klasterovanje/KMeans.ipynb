# %% [markdown]
# # KMeans

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA


from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram
from sklearn.metrics import silhouette_score, homogeneity_score

# %% [markdown]
# Ucitavanje podataka

# %%
data = pd.read_csv('../sredjeni_podaci.csv')

# %%
data
# Out:
#       Unnamed: 0  wave  gender   age  age_o  d_age  d_d_age  race  race_o
# 0              0   1.0       0  21.0   27.0    6.0        2   0.0     1.0  \
# 1              1   1.0       0  21.0   22.0    1.0        0   0.0     1.0
# 2              2   1.0       0  21.0   22.0    1.0        0   0.0     0.0
# 3              3   1.0       0  21.0   23.0    2.0        1   0.0     1.0
# 4              4   1.0       0  21.0   24.0    3.0        1   0.0     3.0
# ...          ...   ...     ...   ...    ...    ...      ...   ...     ...
# 8373        8373  21.0       1  25.0   26.0    1.0        0   1.0     3.0
# 8374        8374  21.0       1  25.0   24.0    1.0        0   1.0     2.0
# 8375        8375  21.0       1  25.0   29.0    4.0        2   1.0     3.0
# 8376        8376  21.0       1  25.0   22.0    3.0        1   1.0     0.0
# 8377        8377  21.0       1  25.0   22.0    3.0        1   1.0     0.0
#
#       samerace  ...  d_expected_num_interested_in_me  d_expected_num_matches
# 0            0  ...                                0                       1  \
# 1            0  ...                                0                       1
# 2            1  ...                                0                       1
# 3            0  ...                                0                       1
# 4            0  ...                                0                       1
# ...        ...  ...                              ...                     ...
# 8373         0  ...                                0                       1
# 8374         0  ...                                0                       1
# 8375         0  ...                                0                       1
# 8376         0  ...                                0                       1
# 8377         0  ...                                0                       1
#
#       like  guess_prob_liked  d_like  d_guess_prob_liked  met  decision
# 0      7.0               6.0       1                   1  0.0         1  \
# 1      7.0               5.0       1                   1  1.0         1
# 2      7.0               5.0       1                   0  1.0         1
# 3      7.0               6.0       1                   1  0.0         1
# 4      6.0               6.0       1                   1  0.0         1
# ...    ...               ...     ...                 ...  ...       ...
# 8373   2.0               5.0       0                   1  0.0         0
# 8374   4.0               4.0       0                   0  0.0         0
# 8375   6.0               5.0       1                   1  0.0         0
# 8376   5.0               5.0       0                   1  0.0         0
# 8377   4.0               5.0       0                   1  0.0         0
#
#       decision_o  match
# 0              0      0
# 1              0      0
# 2              1      1
# 3              1      1
# 4              1      1
# ...          ...    ...
# 8373           1      0
# 8374           0      0
# 8375           0      0
# 8376           1      0
# 8377           1      0
#
# [8378 rows x 122 columns]

# %%
data.drop('Unnamed: 0',axis =1,inplace= True)
X = data.drop('match',axis= 1)

# %%
feature_names = X.columns

# %% [markdown]
# Standardizacija podataka

# %%
scaler = MinMaxScaler()
X = pd.DataFrame(scaler.fit_transform(X), columns=feature_names)

# %% [markdown]
# PCA algoritam za smanjenje dimenzionalnosti:

# %%
pca = PCA()
X = pca.fit_transform(X)

# %%
pca.explained_variance_ratio_[0:2].sum()
# Out:
# 0.1529887071559728

# %% [markdown]
# Sa 2 komponente smo objasnili samo 15% udela ukupne varijanse.

# %%
Y = data['match']
s = plt.scatter(X[:, 0], X[:, 1], c=Y)

# %% [markdown]
# # Izbor otimalnog broja klastera:

# %%
ks = [i for i in range(2, 10)]
sse = []
silh = []
fig, axs = plt.subplots(4, 2, figsize=(10, 20))
fig.suptitle("Broj klastera")

for k, ax in zip(ks, axs.flatten()):
    kmeans = KMeans(n_clusters=k, n_init=10)
    kmeans.fit(X)

    ax.scatter(X[:, 0], X[:, 1], c=kmeans.labels_)
    ax.set_title(f"broj_klastera={k}")
    ax.set_xlabel("pca_{1}")
    ax.set_ylabel("pca_{2}")

    sse.append(kmeans.inertia_)
    silh.append(silhouette_score(X, kmeans.labels_))

plt.tight_layout()
plt.show()

# %% [markdown]
# Za izbor optimalnog broja klastera prvo cemo posmatrati kako se sse menjamo za vreme promene broja klastera, medjutim to nije bas najbolja mera za izbor broja klastera zato sto se sse smanjuje sa povecanjem broja klastera.

# %%
plt.plot(ks, sse,marker = 'o')
plt.xlabel('Broj klastera')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %% [markdown]
# Sada posmatrama promenu Silhouette

# %%
plt.plot(ks, silh,marker = 'o')
plt.xlabel('Broj klastera')
plt.ylabel('Silhouette')
# Out:
# Text(0, 0.5, 'Silhouette')

# %% [markdown]
# Na osnovu pravila lakta zakljucujem da je optimalan broj klastera 4 (ili 5?)

# %%
km = KMeans(n_clusters=4, n_init= 'auto') 
km.fit(X)
# Out:
# KMeans(n_clusters=4, n_init='auto')

# %%
plt.scatter(X[:, 0], X[:, 1], c=km.labels_)

# %%
km = KMeans(n_clusters=5, n_init= 'auto') 
km.fit(X)

plt.scatter(X[:, 0], X[:, 1], c=km.labels_)

# %% [markdown]
# Mislim da je optimalan broj klastera 4,zato sto su tada jasnije granice izmedju klasa.
