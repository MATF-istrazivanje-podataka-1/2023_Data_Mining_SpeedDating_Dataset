# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Ucitavanje podataka:
data = pd.read_csv('speeddating.csv')
# Out:
# <ipython-input-9-150ba2bc9085>:5: DtypeWarning: Columns (3,10,11,15,16,17,18,19,39,40,41,42,43,44,51,52,53,54,55,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,107,109) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('speeddating.csv')

# %% [markdown]
# Analiza podataka

# %%
data.head()
# Out:
#    has_null  wave  gender age age_o  d_age d_d_age
# 0         0     1  female  21    27      6   [4-6]  \
# 1         0     1  female  21    22      1   [0-1]
# 2         1     1  female  21    22      1   [0-1]
# 3         0     1  female  21    23      2   [2-3]
# 4         0     1  female  21    24      3   [2-3]
#
#                                       race
# 0  'Asian/Pacific Islander/Asian-American'  \
# 1  'Asian/Pacific Islander/Asian-American'
# 2  'Asian/Pacific Islander/Asian-American'
# 3  'Asian/Pacific Islander/Asian-American'
# 4  'Asian/Pacific Islander/Asian-American'
#
#                                     race_o  samerace  ...
# 0              European/Caucasian-American         0  ...  \
# 1              European/Caucasian-American         0  ...
# 2  'Asian/Pacific Islander/Asian-American'         1  ...
# 3              European/Caucasian-American         0  ...
# 4               'Latino/Hispanic American'         0  ...
#
#   d_expected_num_interested_in_me d_expected_num_matches like
# 0                           [0-3]                  [3-5]    7  \
# 1                           [0-3]                  [3-5]    7
# 2                           [0-3]                  [3-5]    7
# 3                           [0-3]                  [3-5]    7
# 4                           [0-3]                  [3-5]    6
#
#   guess_prob_liked d_like d_guess_prob_liked met decision decision_o match
# 0                6  [6-8]              [5-6]   0        1          0     0
# 1                5  [6-8]              [5-6]   1        1          0     0
# 2                ?  [6-8]              [0-4]   1        1          1     1
# 3                6  [6-8]              [5-6]   0        1          1     1
# 4                6  [6-8]              [5-6]   0        1          1     1
#
# [5 rows x 123 columns]

# %% [markdown]
# Vidimo da imamo 123 atributa, od cega su 122 za predvidjanje, a poslednji atrbut 'match' nam je ciljni atribut

# %%
data.columns
# Out:
# Index(['has_null', 'wave', 'gender', 'age', 'age_o', 'd_age', 'd_d_age',
#        'race', 'race_o', 'samerace',
#        ...
#        'd_expected_num_interested_in_me', 'd_expected_num_matches', 'like',
#        'guess_prob_liked', 'd_like', 'd_guess_prob_liked', 'met', 'decision',
#        'decision_o', 'match'],
#       dtype='object', length=123)

# %% [markdown]
# Provera nedostajucih vrednosti:

# %%
data.isna()
# Out:
#       has_null   wave  gender    age  age_o  d_age  d_d_age   race  race_o
# 0        False  False   False  False  False  False    False  False   False  \
# 1        False  False   False  False  False  False    False  False   False
# 2        False  False   False  False  False  False    False  False   False
# 3        False  False   False  False  False  False    False  False   False
# 4        False  False   False  False  False  False    False  False   False
# ...        ...    ...     ...    ...    ...    ...      ...    ...     ...
# 8373     False  False   False  False  False  False    False  False   False
# 8374     False  False   False  False  False  False    False  False   False
# 8375     False  False   False  False  False  False    False  False   False
# 8376     False  False   False  False  False  False    False  False   False
# 8377     False  False   False  False  False  False    False  False   False
#
#       samerace  ...  d_expected_num_interested_in_me  d_expected_num_matches
# 0        False  ...                            False                   False  \
# 1        False  ...                            False                   False
# 2        False  ...                            False                   False
# 3        False  ...                            False                   False
# 4        False  ...                            False                   False
# ...        ...  ...                              ...                     ...
# 8373     False  ...                            False                   False
# 8374     False  ...                            False                   False
# 8375     False  ...                            False                   False
# 8376     False  ...                            False                   False
# 8377     False  ...                            False                   False
#
#        like  guess_prob_liked  d_like  d_guess_prob_liked    met  decision
# 0     False             False   False               False  False     False  \
# 1     False             False   False               False  False     False
# 2     False             False   False               False  False     False
# 3     False             False   False               False  False     False
# 4     False             False   False               False  False     False
# ...     ...               ...     ...                 ...    ...       ...
# 8373  False             False   False               False  False     False
# 8374  False             False   False               False  False     False
# 8375  False             False   False               False  False     False
# 8376  False             False   False               False  False     False
# 8377  False             False   False               False  False     False
#
#       decision_o  match
# 0          False  False
# 1          False  False
# 2          False  False
# 3          False  False
# 4          False  False
# ...          ...    ...
# 8373       False  False
# 8374       False  False
# 8375       False  False
# 8376       False  False
# 8377       False  False
#
# [8378 rows x 123 columns]

# %% [markdown]
# Posto je ovako nepregledno, proveravamo da li u svakoj koloni neka nedostajuca vrednost:

# %%
data.isna().any()
# Out:
# has_null              False
# wave                  False
# gender                False
# age                   False
# age_o                 False
#                       ...
# d_guess_prob_liked    False
# met                   False
# decision              False
# decision_o            False
# match                 False
# Length: 123, dtype: bool

# %% [markdown]
# Odavde zakljucujemo da nema nedostajucih vrednosti

# %% [markdown]
# Sledeci korak je podela atributa na one koji sluze za predvidjanje cilja (prvih 122) i ciljni atribut

# %%
Y = data['match']
Y
# Out:
# 0       0
# 1       0
# 2       1
# 3       1
# 4       1
#        ..
# 8373    0
# 8374    0
# 8375    0
# 8376    0
# 8377    0
# Name: match, Length: 8378, dtype: int64

# %%
X = data.drop('match',axis = 1)
X
# Out:
#       has_null  wave  gender age age_o  d_age d_d_age
# 0            0     1  female  21    27      6   [4-6]  \
# 1            0     1  female  21    22      1   [0-1]
# 2            1     1  female  21    22      1   [0-1]
# 3            0     1  female  21    23      2   [2-3]
# 4            0     1  female  21    24      3   [2-3]
# ...        ...   ...     ...  ..   ...    ...     ...
# 8373         1    21    male  25    26      1   [0-1]
# 8374         1    21    male  25    24      1   [0-1]
# 8375         1    21    male  25    29      4   [4-6]
# 8376         1    21    male  25    22      3   [2-3]
# 8377         1    21    male  25    22      3   [2-3]
#
#                                          race
# 0     'Asian/Pacific Islander/Asian-American'  \
# 1     'Asian/Pacific Islander/Asian-American'
# 2     'Asian/Pacific Islander/Asian-American'
# 3     'Asian/Pacific Islander/Asian-American'
# 4     'Asian/Pacific Islander/Asian-American'
# ...                                       ...
# 8373              European/Caucasian-American
# 8374              European/Caucasian-American
# 8375              European/Caucasian-American
# 8376              European/Caucasian-American
# 8377              European/Caucasian-American
#
#                                        race_o  samerace  ...
# 0                 European/Caucasian-American         0  ...  \
# 1                 European/Caucasian-American         0  ...
# 2     'Asian/Pacific Islander/Asian-American'         1  ...
# 3                 European/Caucasian-American         0  ...
# 4                  'Latino/Hispanic American'         0  ...
# ...                                       ...       ...  ...
# 8373               'Latino/Hispanic American'         0  ...
# 8374                                    Other         0  ...
# 8375               'Latino/Hispanic American'         0  ...
# 8376  'Asian/Pacific Islander/Asian-American'         0  ...
# 8377  'Asian/Pacific Islander/Asian-American'         0  ...
#
#      d_expected_happy_with_sd_people d_expected_num_interested_in_me
# 0                              [0-4]                           [0-3]  \
# 1                              [0-4]                           [0-3]
# 2                              [0-4]                           [0-3]
# 3                              [0-4]                           [0-3]
# 4                              [0-4]                           [0-3]
# ...                              ...                             ...
# 8373                          [7-10]                           [0-3]
# 8374                          [7-10]                           [0-3]
# 8375                          [7-10]                           [0-3]
# 8376                          [7-10]                           [0-3]
# 8377                          [7-10]                           [0-3]
#
#      d_expected_num_matches like guess_prob_liked d_like d_guess_prob_liked
# 0                     [3-5]    7                6  [6-8]              [5-6]  \
# 1                     [3-5]    7                5  [6-8]              [5-6]
# 2                     [3-5]    7                ?  [6-8]              [0-4]
# 3                     [3-5]    7                6  [6-8]              [5-6]
# 4                     [3-5]    6                6  [6-8]              [5-6]
# ...                     ...  ...              ...    ...                ...
# 8373                  [3-5]    2                5  [0-5]              [5-6]
# 8374                  [3-5]    4                4  [0-5]              [0-4]
# 8375                  [3-5]    6                5  [6-8]              [5-6]
# 8376                  [3-5]    5                5  [0-5]              [5-6]
# 8377                  [3-5]    4                5  [0-5]              [5-6]
#
#      met decision decision_o
# 0      0        1          0
# 1      1        1          0
# 2      1        1          1
# 3      0        1          1
# 4      0        1          1
# ...   ..      ...        ...
# 8373   0        0          1
# 8374   0        0          0
# 8375   0        0          0
# 8376   0        0          1
# 8377   0        0          1
#
# [8378 rows x 122 columns]

# %% [markdown]
# Analiza podataka:

# %%
X.describe()
# Out:
#          has_null         wave        d_age     samerace     decision
# count  8378.00000  8378.000000  8378.000000  8378.000000  8378.000000  \
# mean      0.87491    11.350919     4.185605     0.395799     0.419909
# std       0.33084     5.995903     4.596171     0.489051     0.493573
# min       0.00000     1.000000     0.000000     0.000000     0.000000
# 25%       1.00000     7.000000     1.000000     0.000000     0.000000
# 50%       1.00000    11.000000     3.000000     0.000000     0.000000
# 75%       1.00000    15.000000     5.000000     1.000000     1.000000
# max       1.00000    21.000000    37.000000     1.000000     1.000000
#
#         decision_o
# count  8378.000000
# mean      0.419551
# std       0.493515
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
Y.describe()
# Out:
# count    8378.000000
# mean        0.164717
# std         0.370947
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: match, dtype: float64

# %%
Y.unique()
# Out:
# array([0, 1])

# %% [markdown]
# Nas ciljni atrbut ima samo dve klase (0 i 1), pa zakljucujemo da se radi o binarnoj klasifikaciji

# %% [markdown]
# Zelimo da vidimo kako su raspodeljene klase, odnosno koliko ima istanci prve, a koliko istanci druge klase

# %%
br1 = 0;
br0 = 0;
for y in Y:
    if y == 1:
        br1+=1
    else:
        br0+=1
print('Broj instanci prve klase: ', br0)
print('Broj instanci druge klase: ',br1)
# Out:
# Broj instanci prve klase:  6998
# Broj instanci druge klase:  1380

# %% [markdown]
# Primecujemo da je broj instanci prve klase znatno veci od broja instanci druge klase.

# %% [markdown]
# Sada podatke delimo na TRENING i TEST skup. 75% ce biti podaci za trening, dok su 25% podaci za testiranje. stratify koristimo da se ne bi desilo da u trening skupu imamo samo instance koje pripadaju prvoj klasi, vec da imamo podatke iz obe klase

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, stratify=Y, random_state=12)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (5613, 122)
# (5613,)
# (2765, 122)
# (2765,)

# %%
print(Y_train.unique())
print(Y_train.unique())
# Out:
# [0 1]
# [0 1]
